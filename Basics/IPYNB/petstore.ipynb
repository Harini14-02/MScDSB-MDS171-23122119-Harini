# %%
class petstore:
    def __init__(self):
        self.pet = {
            "DOGS":[
                {"Pitbull":"Sold",
                 "German":"Not sold",
                 "Lab":"Sold"}],
            "CATS":[
                {"Abyssinian":"Sold",
                 "American Bobtail":"Not Sold",
                 "American Cu":"Sold"}],
            "FISH":[
                {"Koi":"Not Sold",
                 "Fighter":"Not Sold",
                 "Comet":"Not Sold"}],
        }

    def display(self):
        for key, val in self.pet.items():
            for i in val:
                print("{} : {}".format(key, i))
        print("---------------------------------------")
    
    def sell(self):
        flag =0
        breed = input("Enter the pet you want to search - ")
        name = input("Enter the name - ")
        for value in self.pet[breed]:
            for i in self.pet:
                if i == name:
                    print("This breed is available ",name)
                    flag = 1
            if flag == 0:
                print("The breed is not available")
            if value == 'Sold':
                print("Not available for adoption",end='')
                flag = 1
            if flag == 0:
                print("Thank you for the adoption \n",end='')

    def search(self):
        flag =0
        breed = input("Enter the pet you want to search - ")
        name = input("Enter the name - ")
        for item in self.pet[breed]:
                for i in item:
                    if i == name:
                        print("This breed is available ",name)
                        flag = 1
                if flag == 0:
                    print("The breed is not available")


    def store(self):
        my_dict = {}
        breed = input("Enter the breed - ")
        sold = input("Sold or Not Sold - ")
        my_dict['Breed']=breed
        my_dict['Availabilty']=sold
        print(my_dict)



a = petstore()
a.display()
a.search()
a.sell()
a.store()
# Out:
# DOGS : {'Pitbull': 'Sold', 'German': 'Not sold', 'Lab': 'Sold'}
# CATS : {'Abyssinian': 'Sold', 'American Bobtail': 'Not Sold', 'American Cu': 'Sold'}
# FISH : {'Koi': 'Not Sold', 'Fighter': 'Not Sold', 'Comet': 'Not Sold'}
# ---------------------------------------
# This breed is available  Lab
# The breed is not available
# Thank you for the adoption
# {'Breed': 'DOGS', 'Availabilty': 'Sold'}

# %%
class PetStore:
    def __init__(self):
        self.pet = {
            "dogs": {
                "Pitbull": "Sold",
                "German": "Not sold",
                "Lab": "Sold"
            },
            "cats": {
                "Abyssinian": "Sold",
                "American Bobtail": "Not sold",
                "American Cu": "Sold"
            },
            "fish": {
                "Koi": "Not sold",
                "Fighter": "Not sold",
                "Comet": "Not sold"
            }
        }

    def display(self):
        for category, pets in self.pet.items():
            for breed, availability in pets.items():
                print(f"{category} - {breed}: {availability}")
        print("---------------------------------------")

    def sell(self):
        breed = input("Enter the pet category you want to search - ").upper()
        name = input("Enter the breed - ")
        
        if breed in self.pet and name in self.pet[breed]:
            if self.pet[breed][name] == 'Sold':
                print(f"{name} is not available for adoption.")
            else:
                print(f"Thank you for adopting {name}.")
        else:
            print("The breed is not available.")

    def search(self):
        breed = input("Enter the pet category you want to search - ").upper()
        name = input("Enter the breed - ")
        
        if breed in self.pet and name in self.pet[breed]:
            print(f"{name} is available in the {breed} category.")
        else:
            print("The breed is not available.")

    def store(self):
        breed = input("Enter the pet category you want to update - ").upper()
        name = input("Enter the breed - ")
        availability = input("Enter the availability (Sold or Not Sold) - ").capitalize()

        if breed in self.pet and name in self.pet[breed]:
            self.pet[breed][name] = availability
            print(f"{name} in the {breed} category is now marked as {availability}.")
        else:
            print("The breed or category is not found in the store.")

a = PetStore()
a.display()
a.search()
a.sell()
a.store()
# Out:
# DOGS - Pitbull: Sold
# DOGS - German: Not sold
# DOGS - Lab: Sold
# CATS - Abyssinian: Sold
# CATS - American Bobtail: Not sold
# CATS - American Cu: Sold
# FISH - Koi: Not sold
# FISH - Fighter: Not sold
# FISH - Comet: Not sold
# ---------------------------------------
# Lab is available in the DOGS category.
# Lab is not available for adoption.
# Koi in the FISH category is now marked as Sold.
